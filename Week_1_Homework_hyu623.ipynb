# %% [markdown]
# <a href="https://colab.research.google.com/github/hyu623/week4trial/blob/main/Week_1_Homework_hyu623.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
response = requests.get("https://katiemik.github.io/urban-family-recipe-collection/")
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://katiemik.github.io/urban-family-recipe-collection/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "objectid": "recipe003",
#   "filename": "recipe003.pdf",
#   "format": "application/pdf",
#   "title": "Stuffed Cabbage Leaves (Go\u0142\u0105bki)",
#   "creator": "Josh Clary",
#   "description": "Our friends Jack and Kelly who lived in Romania for years introduced us to this dish and we make it often. It's really solid comfort food and is easily riffable",
#   "subject": "recipe",
#   "mealtype": "entree",
#   "mainingredient": "cabbage; pork; beef",
#   "seasonality": "spring; fall; winter",
#   "cookingmethod": "stovetop; oven",
#   "reference_url": "https://katiemik.github.io/urban-family-recipe-collection/item.html?id=recipe003"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://katiemik.github.io/urban-family-recipe-collection/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "objectid",
#       "terms": {
#         "image001": 1,
#         "recipe001": 1,
#         "recipe002": 1,
#         "recipe003": 1,
#         "recipe004": 1,
#         "recipe005": 1,
#         "recipe006": 1,
#         "recipe007": 1,
#         "recipe008": 1,
#         "recipe009": 1,
#         "recipe010": 1,
#         "recipe011": 1,
#         "recipe012": 1,
#         "recipe013": 1,
#         "recipe014": 1,
#         "recipe015": 1,
#         "recipe016": 1,
#         "recipe017": 1,
#         "recipe018": 1,
#         "recipe019": 1,
#         "recipe020": 1
#       }
#     },
#     {
#       "field": "filename",
#       "terms": {
#         "image001.jpg": 1,
#         "recipe001.pdf": 1,
#         "recipe002.pdf": 1,
#         "recipe003.pdf": 1,
#         "recipe004.pdf": 1,
#         "recipe005.pdf": 1,
#         "recipe006.pdf": 1,
#         "recipe007.pdf": 1,
#         "recipe008.pdf": 1,
#         "recipe009.pdf": 1,
#         "recipe010.pdf": 1,
#         "recipe011.pdf": 1,
#         "recipe012.pdf": 1,
#         "recipe013.pdf": 1,
#         "recipe014.pdf": 1,
#         "recipe015.pdf": 1,
#         "recipe016.pdf": 1,
#         "recipe017.pdf": 1,
#         "recipe018.pdf": 1,
#         "recipe019.pdf": 1,
#         "recipe020.pdf": 1
#       }
#     },
#     {
#       "field": "format",
#       "terms": {
#         "application/pdf": 20,
#         "image/jpg": 1
#       }
#     },
#     {
#       "field": "title",
#       "terms": {
#         "baked tofu with peanut sauce and coconut-lime rice": 1,
#         "brown butter apple loaf": 1,
#         "butternut squash soup": 1,
#         "chicken and stuffing with italian seasonings": 1,
#         "chili lime seasoning": 1,
#         "cover photo": 1,
#         "farmer\u2019s market frittata": 1,
#         "glazed sweet potato with lentils": 1,
#         "green beans with tomatoes, onions, and beans": 1,
#         "green hummus": 1,
#         "josh's thai peanut soup": 1,
#         "joy\u2019s morning smoothie 1": 1,
#         "katie\u2019s caramelized onion dip": 1,
#         "kimchi toast": 1,
#         "ksb (kale sausage beans)": 1,
#         "minestrone soup": 1,
#         "pa\u2019s chili": 1,
#         "popcorn seasoning": 1,
#         "roasted butternut squash & apple soup with bacon": 1,
#         "stuffed cabbage leaves (go\u0142\u0105bki)": 1,
#         "texas hash": 1
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {
#         "donald urban": 2,
#         "emy urban": 2,
#         "esther urban": 1,
#         "josh clary": 5,
#         "joy urban": 3,
#         "katie mikulka": 3,
#         "kristine makiewicz": 1,
#         "kurt makiewicz": 2,
#         "laura urban": 2,
#         "leslie urban": 2
#       }
#     },
#     {
#       "field": "description",
#       "terms": {
#         "as someone who has always pooh-poohed lentils, this is the recipe that made me a convert. i'll often bake the sweet potatoes as soon as i get home from the grocery, so on the evening i am eating it all it takes is the 20ish minutes it takes to cook the lentils to throw this all together.": 1,
#         "don\u2019t omit the anchovy. it does not make the dish taste fishy but adds a magically savory flavor.": 1,
#         "emy and i have started making frittatas whenever we need a quick dinner or/and have a surplus of languishing produce. both factors are usually in play on friday nights, when both energy and fresh groceries are dangerously low. but its four portions are perfect for dinner on friday and reheated leftovers make for a post farmer\u2019s market brunch on saturday. the veggie, dairy, and cheese combinations are endless here. but be aware of the moisture content, as that can prevent the frittata from setting. an overzealous attempt to use up a lot of tomatoes taught us that lesson the hard way... leafy greens\u2014 like collards, spinach, and kale\u2014shine here, as do onions, peppers, and mushrooms. leftover meat or browned sausage would also be a delight! the options are endless. serve with toast or potatoes.would also be a delight! the options are endless. serve with toast or potatoes.would also be a delight! the options are endless. serve with toast or potatoes.": 1,
#         "here's one of our favorite soups. it is written for a pressure cooker but can be done in a slow cooker or stovetop.": 1,
#         "i like to use v8 juice because it adds some unique flavors. they may use tomato juice if they want.": 1,
#         "i make this every year we go apple picking. it's a lot easier than making a pie and has a really nice texture from the nuts.": 1,
#         "i'm always looking for new interesting ways to eat this low-on-the-food-chain and so-healthy protein. tofu is like a blank slate that plays well with strong flavors, so spicy peanut butter makes for an easy sauce. with the raw greens and hot coconutty-rice, the mix of textures is really satisfying. this is one of my new favorite go-to options.": 1,
#         "onion dip is perhaps one of earth\u2019s most perfect foods. this version, simplified and adapted from alison roman, is next level: sweet from the caramelized onions, a little spicy from the raw garlic, and incredibly creamy from the mix of dairy. cooking the onions is time-consuming, but well worth it. listen to a podcast while you stir, and your patience will be rewarded.": 1,
#         "our friends jack and kelly who lived in romania for years introduced us to this dish and we make it often. it's really solid comfort food and is easily riffable": 1,
#         "peanut soup in virginia is a regional tradition. i've had a lot of them, and many i didn't like. i came up with this thai inspired version that is a great pantry ingredient soup.": 1,
#         "simple but so tasty! the crusty french bread is key to making this feel like a filling meal on weekdays.": 1,
#         "the bacon and apple really add depth and brightness to this soup.": 1,
#         "this dish is one our favorites and has been for many years. sprinkling with parmesan is really good.": 1,
#         "this fall, katie and i have gotten quite a few squashes in our csa and we've found this soup is an easy and delicious way to use it up. the ginger and the rosemary/sage make for such a good flavor combination and we use our immersion blender to make it super creamy. we eat it with a side of crusty bread with butter. makes for a pretty perfect fall lunch!": 1,
#         "this has become our sunday breakfast since we get fresh bread delivered on saturday.": 1,
#         "this is from pepperscale.com. for an easy potluck dish i mix some up and toss with fresh pineapple chunks. grind the spices yourself for the best flavor.": 1,
#         "this recipe i found on a blog i've read for years \u201ca cup of jo.\" they titled it \u201cthis dinner is so good, it has a nickname!\u201d when i first read the recipe i wasn't totally convinced, but we made it once and it became a staple. once kurt and i started loving ksb we became ksb evangelists! what i love now it that there are at least 3-4 friend / family groups that now have ksb as part of their go-to dinner recipes. we get messages all the time, \u2018it\u2019s a ksb night!\u201d we love it with spicy italian sausage, two bunches of kale and two cans of beans to really get the ratio right\"": 1,
#         "when you're tired of the regular hummus, which is flavored with lemon and soy sauce, and you have kale to use up from the bunch, try this one -- so good!": 1
#       }
#     },
#     {
#       "field": "subject",
#       "terms": {
#         "recipe": 20
#       }
#     },
#     {
#       "field": "mealtype",
#       "terms": {
#         "appetizer/snack": 2,
#         "breakfast": 2,
#         "condiment/seasoning": 2,
#         "dessert": 1,
#         "entree": 13
#       }
#     },
#     {
#       "field": "mainingredient",
#       "terms": {
#         "apple": 2,
#         "bacon": 1,
#         "bean": 4,
#         "beef": 3,
#         "blueberry": 1,
#         "bread": 1,
#         "brown butter": 1,
#         "bulgur": 1,
#         "butternut squash": 2,
#         "cabbage": 2,
#         "carrot": 1,
#         "cheese": 1,
#         "chicken": 1,
#         "chickpea": 1,
#         "chili powder": 1,
#         "coconut": 1,
#         "egg": 1,
#         "green bean": 1,
#         "kale": 3,
#         "kimchi": 1,
#         "lentil": 1,
#         "lime": 2,
#         "mushroom": 1,
#         "nutritional yeast": 1,
#         "onion": 2,
#         "peanut": 2,
#         "pork": 1,
#         "rice": 2,
#         "sausage": 1,
#         "spinach": 1,
#         "sweet potato": 1,
#         "tofu": 1,
#         "tomato": 3,
#         "vegetable": 1
#       }
#     },
#     {
#       "field": "seasonality",
#       "terms": {
#         "all seasons": 12,
#         "fall": 7,
#         "spring": 4,
#         "summer": 1,
#         "winter": 7
#       }
#     },
#     {
#       "field": "cookingmethod",
#       "terms": {
#         "no cook": 5,
#         "oven": 8,
#         "stovetop": 15
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - objectid
# - filename
# - format
# - title
# - creator
# - description
# - subject
# - mealtype
# - mainingredient
# - seasonality
# - cookingmethod
# - reference_url

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is recipe. It is used 20 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#      objectid       filename           format  \
# 0   recipe001  recipe001.pdf  application/pdf
# 1   recipe002  recipe002.pdf  application/pdf
# 2   recipe003  recipe003.pdf  application/pdf
# 3   recipe004  recipe004.pdf  application/pdf
# 4   recipe005  recipe005.pdf  application/pdf
# 5   recipe006  recipe006.pdf  application/pdf
# 6   recipe007  recipe007.pdf  application/pdf
# 7   recipe008  recipe008.pdf  application/pdf
# 8   recipe009  recipe009.pdf  application/pdf
# 9   recipe010  recipe010.pdf  application/pdf
# 10  recipe011  recipe011.pdf  application/pdf
# 11  recipe012  recipe012.pdf  application/pdf
# 12  recipe013  recipe013.pdf  application/pdf
# 13  recipe014  recipe014.pdf  application/pdf
# 14  recipe015  recipe015.pdf  application/pdf
# 15  recipe016  recipe016.pdf  application/pdf
# 16  recipe017  recipe017.pdf  application/pdf
# 17  recipe018  recipe018.pdf  application/pdf
# 18  recipe019  recipe019.pdf  application/pdf
# 19  recipe020  recipe020.pdf  application/pdf
# 20   image001   image001.jpg        image/jpg
#
#                                                 title  \
# 0                            KSB (Kale Sausage Beans)
# 1        Chicken and Stuffing with Italian Seasonings
# 2                    Stuffed Cabbage Leaves (Gołąbki)
# 3   Baked Tofu with Peanut Sauce and Coconut-Lime ...
# 4                                          Texas Hash
# 5                    Glazed Sweet Potato with Lentils
# 6                            Farmer’s Market Frittata
# 7                                        Kimchi Toast
# 8                                   Popcorn Seasoning
# 9                                Chili Lime Seasoning
# 10       Green Beans with Tomatoes, Onions, and Beans
# 11                                       Green Hummus
# 12                              Butternut Squash Soup
# 13                                         Pa’s Chili
# 14                            Josh's Thai Peanut Soup
# 15                                    Minestrone Soup
# 16   Roasted Butternut Squash & Apple Soup with Bacon
# 17                           Joy’s Morning Smoothie 1
# 18                      Katie’s Caramelized Onion Dip
# 19                            Brown Butter Apple Loaf
# 20                                        Cover Photo
#
#                        creator  \
# 0           Kristine Makiewicz
# 1                    Joy Urban
# 2                   Josh Clary
# 3                  Laura Urban
# 4   Donald Urban; Esther Urban
# 5                 Leslie Urban
# 6     Katie Mikulka; Emy Urban
# 7               Kurt Makiewicz
# 8                   Josh Clary
# 9                    Joy Urban
# 10                Leslie Urban
# 11                 Laura Urban
# 12    Katie Mikulka; Emy Urban
# 13                Donald Urban
# 14                  Josh Clary
# 15              Kurt Makiewicz
# 16                  Josh Clary
# 17                   Joy Urban
# 18               Katie Mikulka
# 19                  Josh Clary
# 20                         NaN
#
#                                           description subject  \
# 0   This recipe I found on a blog I've read for ye...  recipe
# 1   Don’t omit the anchovy. It does not make the d...  recipe
# 2   Our friends Jack and Kelly who lived in Romani...  recipe
# 3   I'm always looking for new interesting ways to...  recipe
# 4   This dish is one our favorites and has been fo...  recipe
# 5   As someone who has always pooh-poohed lentils,...  recipe
# 6   Emy and I have started making frittatas whenev...  recipe
# 7   This has become our Sunday breakfast since we ...  recipe
# 8                                                 NaN  recipe
# 9   This is from Pepperscale.com. For an easy potl...  recipe
# 10  Simple but so tasty! The crusty French bread i...  recipe
# 11  When you're tired of the regular hummus, which...  recipe
# 12  This fall, Katie and I have gotten quite a few...  recipe
# 13  I like to use V8 juice because it adds some un...  recipe
# 14  Peanut Soup in Virginia is a regional traditio...  recipe
# 15  Here's one of our favorite soups. It is writte...  recipe
# 16  The bacon and apple really add depth and brigh...  recipe
# 17                                                NaN  recipe
# 18  Onion dip is perhaps one of earth’s most perfe...  recipe
# 19  I make this every year we go apple picking. It...  recipe
# 20                                                NaN     NaN
#
#                mealtype                     mainingredient  \
# 0                entree                kale; sausage; bean
# 1                entree         chicken; spinach; mushroom
# 2                entree                cabbage; pork; beef
# 3                entree  tofu; peanut; coconut; lime; rice
# 4                entree                 beef; rice; tomato
# 5                entree               lentil; sweet potato
# 6                entree             egg; cheese; vegetable
# 7             breakfast                      kimchi; bread
# 8   condiment/seasoning                  nutritional yeast
# 9   condiment/seasoning                 chili powder; lime
# 10               entree    green bean; tomato; onion; bean
# 11      appetizer/snack               chickpea; bean; kale
# 12               entree                   butternut squash
# 13               entree                       beef; tomato
# 14               entree                             peanut
# 15               entree              cabbage; bean; bulgur
# 16               entree     butternut squash; apple; bacon
# 17            breakfast            kale; blueberry; carrot
# 18      appetizer/snack                              onion
# 19              dessert                apple; brown butter
# 20                  NaN                                NaN
#
#              seasonality   cookingmethod  \
# 0   spring; fall; winter        stovetop
# 1            all seasons  stovetop; oven
# 2   spring; fall; winter  stovetop; oven
# 3            all seasons  stovetop; oven
# 4            all seasons  stovetop; oven
# 5           fall; winter  stovetop; oven
# 6            all seasons  stovetop; oven
# 7            all seasons         no cook
# 8            all seasons         no cook
# 9            all seasons         no cook
# 10                summer        stovetop
# 11  spring; fall; winter         no cook
# 12          fall; winter        stovetop
# 13           all seasons        stovetop
# 14           all seasons        stovetop
# 15  spring; fall; winter        stovetop
# 16          fall; winter  stovetop; oven
# 17           all seasons         no cook
# 18           all seasons        stovetop
# 19           all seasons  stovetop; oven
# 20                   NaN             NaN
#
#                                         reference_url
# 0   https://katiemik.github.io/urban-family-recipe...
# 1   https://katiemik.github.io/urban-family-recipe...
# 2   https://katiemik.github.io/urban-family-recipe...
# 3   https://katiemik.github.io/urban-family-recipe...
# 4   https://katiemik.github.io/urban-family-recipe...
# 5   https://katiemik.github.io/urban-family-recipe...
# 6   https://katiemik.github.io/urban-family-recipe...
# 7   https://katiemik.github.io/urban-family-recipe...
# 8   https://katiemik.github.io/urban-family-recipe...
# 9   https://katiemik.github.io/urban-family-recipe...
# 10  https://katiemik.github.io/urban-family-recipe...
# 11  https://katiemik.github.io/urban-family-recipe...
# 12  https://katiemik.github.io/urban-family-recipe...
# 13  https://katiemik.github.io/urban-family-recipe...
# 14  https://katiemik.github.io/urban-family-recipe...
# 15  https://katiemik.github.io/urban-family-recipe...
# 16  https://katiemik.github.io/urban-family-recipe...
# 17  https://katiemik.github.io/urban-family-recipe...
# 18  https://katiemik.github.io/urban-family-recipe...
# 19  https://katiemik.github.io/urban-family-recipe...
# 20  https://katiemik.github.io/urban-family-recipe...

# %%
# Run this a few times to see random entries in your dataframe %% [markdown]
# **H6** This is for bonus! Try to write a pandas statement that will display
# your answer from **H4**. There are plenty of ways to do this, so feel free to
# use your imagination. What I have started for you here might not work, so feel
# free to change it as needed. %%

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
No idea how to write the code for this question. Would like to see your guidance. Thanks.

# %%
cb_normalized[cb_normalized["subject"] == "recipe"].count()
# Out:
# objectid          20
# filename          20
# format            20
# title             20
# creator           20
# description       18
# subject           20
# mealtype          20
# mainingredient    20
# seasonality       20
# cookingmethod     20
# reference_url     20
# dtype: int64

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
